# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import BatchNormalization
# %matplotlib inline
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.7)  
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95
PATIENCE = [10, 25]

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: Earlystop
"""
earlystop = EarlyStopping(monitor="val_loss", 
                          patience=5, 
                          verbose=1
                          )

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for pa in PATIENCE:
    keras.backend.clear_session()
    print("PATIENCE = %.1f" % (pa))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[earlystop]
         )
    exp_name_tag = ("PATIENCE = %.1f" % (pa))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# PATIENCE = 10.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 49/49 [==============================] - 1s 14ms/step - loss: 2.2062 - accuracy: 0.2692 - val_loss: 2.1477 - val_accuracy: 0.1965
# Epoch 2/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.7288 - accuracy: 0.3937 - val_loss: 1.9488 - val_accuracy: 0.3145
# Epoch 3/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.6105 - accuracy: 0.4335 - val_loss: 1.7984 - val_accuracy: 0.3872
# Epoch 4/50
# 49/49 [==============================] - 0s 9ms/step - loss: 1.5408 - accuracy: 0.4574 - val_loss: 1.7018 - val_accuracy: 0.4149
# Epoch 5/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.4869 - accuracy: 0.4756 - val_loss: 1.6329 - val_accuracy: 0.4279
# Epoch 6/50
# 49/49 [==============================] - 0s 9ms/step - loss: 1.4426 - accuracy: 0.4933 - val_loss: 1.5800 - val_accuracy: 0.4421
# Epoch 7/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.4015 - accuracy: 0.5074 - val_loss: 1.5514 - val_accuracy: 0.4532
# Epoch 8/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3666 - accuracy: 0.5202 - val_loss: 1.5191 - val_accuracy: 0.4631
# Epoch 9/50
# 49/49 [==============================] - 1s 10ms/step - loss: 1.3336 - accuracy: 0.5308 - val_loss: 1.4980 - val_accuracy: 0.4660
# Epoch 10/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.3038 - accuracy: 0.5432 - val_loss: 1.4923 - val_accuracy: 0.4692
# Epoch 11/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2740 - accuracy: 0.5537 - val_loss: 1.4818 - val_accuracy: 0.4758
# Epoch 12/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2468 - accuracy: 0.5648 - val_loss: 1.4798 - val_accuracy: 0.4810
# Epoch 13/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.2230 - accuracy: 0.5734 - val_loss: 1.4640 - val_accuracy: 0.4811
# Epoch 14/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1977 - accuracy: 0.5830 - val_loss: 1.4660 - val_accuracy: 0.4806
# Epoch 15/50
# 49/49 [==============================] - 1s 10ms/step - loss: 1.1724 - accuracy: 0.5931 - val_loss: 1.4667 - val_accuracy: 0.4860
# Epoch 16/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.1471 - accuracy: 0.6025 - val_loss: 1.4513 - val_accuracy: 0.4873
# Epoch 17/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1238 - accuracy: 0.6117 - val_loss: 1.4659 - val_accuracy: 0.4845
# Epoch 18/50
# 49/49 [==============================] - 1s 10ms/step - loss: 1.1007 - accuracy: 0.6205 - val_loss: 1.4465 - val_accuracy: 0.4931
# Epoch 19/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0789 - accuracy: 0.6307 - val_loss: 1.4653 - val_accuracy: 0.4874
# Epoch 20/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.0572 - accuracy: 0.6385 - val_loss: 1.4629 - val_accuracy: 0.4906
# Epoch 21/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0347 - accuracy: 0.6465 - val_loss: 1.4707 - val_accuracy: 0.4848
# Epoch 22/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0128 - accuracy: 0.6538 - val_loss: 1.4432 - val_accuracy: 0.4980
# Epoch 23/50
# 49/49 [==============================] - 1s 11ms/step - loss: 0.9893 - accuracy: 0.6652 - val_loss: 1.4470 - val_accuracy: 0.4988
# Epoch 24/50
# 49/49 [==============================] - 1s 10ms/step - loss: 0.9704 - accuracy: 0.6720 - val_loss: 1.4505 - val_accuracy: 0.4957
# Epoch 25/50
# 49/49 [==============================] - 0s 10ms/step - loss: 0.9460 - accuracy: 0.6819 - val_loss: 1.4933 - val_accuracy: 0.4888
# Epoch 26/50
# 49/49 [==============================] - 0s 10ms/step - loss: 0.9272 - accuracy: 0.6904 - val_loss: 1.4650 - val_accuracy: 0.4952
# Epoch 27/50
# 49/49 [==============================] - 0s 10ms/step - loss: 0.9072 - accuracy: 0.6969 - val_loss: 1.4727 - val_accuracy: 0.5004
# Epoch 00027: early stopping
# PATIENCE = 25.0
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 49/49 [==============================] - 1s 13ms/step - loss: 2.2046 - accuracy: 0.2722 - val_loss: 2.0922 - val_accuracy: 0.2474
# Epoch 2/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.7397 - accuracy: 0.3914 - val_loss: 1.9602 - val_accuracy: 0.3038
# Epoch 3/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.6145 - accuracy: 0.4357 - val_loss: 1.8173 - val_accuracy: 0.3609
# Epoch 4/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.5416 - accuracy: 0.4600 - val_loss: 1.7124 - val_accuracy: 0.3971
# Epoch 5/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4901 - accuracy: 0.4797 - val_loss: 1.6301 - val_accuracy: 0.4235
# Epoch 6/50
# 49/49 [==============================] - 1s 10ms/step - loss: 1.4454 - accuracy: 0.4944 - val_loss: 1.5825 - val_accuracy: 0.4408
# Epoch 7/50
# 49/49 [==============================] - 1s 11ms/step - loss: 1.4061 - accuracy: 0.5104 - val_loss: 1.5549 - val_accuracy: 0.4447
# Epoch 8/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3724 - accuracy: 0.5229 - val_loss: 1.5326 - val_accuracy: 0.4582
# Epoch 9/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3408 - accuracy: 0.5347 - val_loss: 1.5094 - val_accuracy: 0.4673
# Epoch 10/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.3097 - accuracy: 0.5447 - val_loss: 1.4906 - val_accuracy: 0.4746
# Epoch 11/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2833 - accuracy: 0.5562 - val_loss: 1.4892 - val_accuracy: 0.4722
# Epoch 12/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2567 - accuracy: 0.5658 - val_loss: 1.4862 - val_accuracy: 0.4749
# Epoch 13/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2309 - accuracy: 0.5767 - val_loss: 1.4698 - val_accuracy: 0.4812
# Epoch 14/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.2054 - accuracy: 0.5833 - val_loss: 1.4672 - val_accuracy: 0.4780
# Epoch 15/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1839 - accuracy: 0.5911 - val_loss: 1.4638 - val_accuracy: 0.4853
# Epoch 16/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1588 - accuracy: 0.6005 - val_loss: 1.4584 - val_accuracy: 0.4881
# Epoch 17/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1364 - accuracy: 0.6097 - val_loss: 1.4582 - val_accuracy: 0.4903
# Epoch 18/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.1145 - accuracy: 0.6183 - val_loss: 1.4520 - val_accuracy: 0.4903
# Epoch 19/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0925 - accuracy: 0.6264 - val_loss: 1.4480 - val_accuracy: 0.4928
# Epoch 20/50
# 49/49 [==============================] - 1s 15ms/step - loss: 1.0699 - accuracy: 0.6352 - val_loss: 1.4544 - val_accuracy: 0.4908
# Epoch 21/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0485 - accuracy: 0.6440 - val_loss: 1.4537 - val_accuracy: 0.4893
# Epoch 22/50
# 49/49 [==============================] - 0s 10ms/step - loss: 1.0268 - accuracy: 0.6520 - val_loss: 1.4610 - val_accuracy: 0.4952
# Epoch 23/50
# 49/49 [==============================] - 1s 10ms/step - loss: 1.0067 - accuracy: 0.6586 - val_loss: 1.4517 - val_accuracy: 0.4917
# Epoch 24/50
# 49/49 [==============================] - 0s 10ms/step - loss: 0.9859 - accuracy: 0.6672 - val_loss: 1.4759 - val_accuracy: 0.4938
# Epoch 00024: early stopping

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
